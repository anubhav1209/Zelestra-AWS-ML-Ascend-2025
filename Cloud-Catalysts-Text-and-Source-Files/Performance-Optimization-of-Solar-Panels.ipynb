# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# ----------------------------
# 1. LOAD DATA AND PREPROCESSING
# ----------------------------
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
test_ids = test["id"]

for df in [train, test]:
    for col in ["id", "string_id"]:
        if col in df.columns:
            df.drop(columns=[col], inplace=True)

for col in ["humidity", "wind_speed", "pressure"]:
    train[col] = pd.to_numeric(train[col], errors="coerce")
    test[col]  = pd.to_numeric(test[col], errors="coerce")

numeric_cols = ["humidity", "wind_speed", "pressure"]
for col in numeric_cols:
    median_val = train[col].median()
    train[col] = train[col].fillna(median_val)
    test[col]  = test[col].fillna(median_val)

categorical_cols = ["installation_type", "error_code"]
for col in categorical_cols:
    train[col] = train[col].astype(str)
    test[col]  = test[col].astype(str)

train = pd.get_dummies(train, columns=categorical_cols)
test = pd.get_dummies(test, columns=categorical_cols)

train, test = train.align(test, join="left", axis=1, fill_value=0)

X = train.drop(columns=["efficiency"])
y = train["efficiency"]

X = X.fillna(0)
test = test.fillna(0)

# ----------------------------
# 2. FEATURE SCALING
# ----------------------------
test_features = test.drop(columns=["efficiency"], errors="ignore")
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
test_scaled = scaler.transform(test_features)

# ----------------------------
# 3. TRAIN–VALIDATION SPLIT (90:10)
# ----------------------------
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.10, random_state=42)

# ----------------------------
# 4. TRAIN BASE MODELS
# ----------------------------
# XGBoost
xgb_model = xgb.XGBRegressor(
    n_estimators=1000, learning_rate=0.03, max_depth=6,
    subsample=0.80, colsample_bytree=0.80,
    objective="reg:squarederror", eval_metric="rmse",
    verbosity=1, random_state=42, n_jobs=-1
)
xgb_model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=True)

# LightGBM
lgb_model = lgb.LGBMRegressor(
    n_estimators=1000, learning_rate=0.03, max_depth=6,
    subsample=0.80, colsample_bytree=0.80,
    objective="regression", metric="rmse",
    random_state=42, n_jobs=-1
)
lgb_callbacks = [lgb.early_stopping(stopping_rounds=50, verbose=True)]
lgb_model.fit(X_train, y_train, eval_set=[(X_val, y_val)], callbacks=lgb_callbacks)

# CatBoost
cat_model = CatBoostRegressor(
    iterations=1000, learning_rate=0.03, depth=6,
    loss_function='RMSE', random_seed=42,
    verbose=False
)
cat_model.fit(X_train, y_train, eval_set=(X_val, y_val), verbose=False)

# RandomForest
rf_model = RandomForestRegressor(
    n_estimators=300, max_depth=10,
    random_state=42, n_jobs=-1
)
rf_model.fit(X_train, y_train)

# AdaBoostRegressor
ada_model = AdaBoostRegressor(
    n_estimators=300, learning_rate=0.03, random_state=42
)
ada_model.fit(X_train, y_train)

# ----------------------------
# 5. BUILD STACKED FEATURES
# ----------------------------
xgb_val_preds = xgb_model.predict(X_val)
lgb_val_preds = lgb_model.predict(X_val)
cat_val_preds = cat_model.predict(X_val)
rf_val_preds = rf_model.predict(X_val)
ada_val_preds = ada_model.predict(X_val)

stacked_val = np.column_stack((xgb_val_preds, lgb_val_preds, cat_val_preds, rf_val_preds, ada_val_preds))

xgb_test_preds = xgb_model.predict(test_scaled)
lgb_test_preds = lgb_model.predict(test_scaled)
cat_test_preds = cat_model.predict(test_scaled)
rf_test_preds = rf_model.predict(test_scaled)
ada_test_preds = ada_model.predict(test_scaled)
stacked_test = np.column_stack((xgb_test_preds, lgb_test_preds, cat_test_preds, rf_test_preds, ada_test_preds))

# ----------------------------
# 6. TRAIN META MODEL (RIDGE) WITH GRID SEARCH
# ----------------------------
param_grid = {"alpha": [0.01, 0.1, 0.3, 1, 3, 10]}
ridge = Ridge(random_state=42)
grid_search = GridSearchCV(ridge, param_grid, scoring="neg_mean_squared_error", cv=5)
grid_search.fit(stacked_val, y_val)
meta_model = grid_search.best_estimator_
print("Best Ridge alpha:", grid_search.best_params_["alpha"])

val_preds = meta_model.predict(stacked_val)
val_rmse = np.sqrt(mean_squared_error(y_val, val_preds))
custom_score = 100 * (1 - val_rmse)
print(f"✅ Validation RMSE: {val_rmse:.4f}")
print(f"✅ Custom Score: {custom_score:.2f}/100")

# ----------------------------
# 7. FINAL TEST PREDICTIONS AND SUBMISSION
# ----------------------------
final_test_preds = meta_model.predict(stacked_test)
submission = pd.DataFrame({"id": test_ids, "efficiency": final_test_preds})
submission.to_csv("submission.csv", index=False)
print("✅ 'submission.csv' created successfully.")
# Out:
# [0]	validation_0-rmse:0.14264
# [1]	validation_0-rmse:0.14114
# [2]	validation_0-rmse:0.14054
# [3]	validation_0-rmse:0.13910
# [4]	validation_0-rmse:0.13776
# [5]	validation_0-rmse:0.13649
# [6]	validation_0-rmse:0.13618
# [7]	validation_0-rmse:0.13500
# [8]	validation_0-rmse:0.13387
# [9]	validation_0-rmse:0.13348
# [10]	validation_0-rmse:0.13237
# [11]	validation_0-rmse:0.13139
# [12]	validation_0-rmse:0.13053
# [13]	validation_0-rmse:0.12957
# [14]	validation_0-rmse:0.12870
# [15]	validation_0-rmse:0.12784
# [16]	validation_0-rmse:0.12706
# [17]	validation_0-rmse:0.12630
# [18]	validation_0-rmse:0.12558
# [19]	validation_0-rmse:0.12532
# [20]	validation_0-rmse:0.12462
# [21]	validation_0-rmse:0.12396
# [22]	validation_0-rmse:0.12344
# [23]	validation_0-rmse:0.12289
# [24]	validation_0-rmse:0.12234
# [25]	validation_0-rmse:0.12181
# [26]	validation_0-rmse:0.12131
# [27]	validation_0-rmse:0.12088
# [28]	validation_0-rmse:0.12053
# [29]	validation_0-rmse:0.12009
# [30]	validation_0-rmse:0.11977
# [31]	validation_0-rmse:0.11935
# [32]	validation_0-rmse:0.11896
# [33]	validation_0-rmse:0.11880
# [34]	validation_0-rmse:0.11845
# [35]	validation_0-rmse:0.11815
# [36]	validation_0-rmse:0.11790
# [37]	validation_0-rmse:0.11762
# [38]	validation_0-rmse:0.11733
# [39]	validation_0-rmse:0.11710
# [40]	validation_0-rmse:0.11685
# [41]	validation_0-rmse:0.11662
# [42]	validation_0-rmse:0.11640
# [43]	validation_0-rmse:0.11621
# [44]	validation_0-rmse:0.11600
# [45]	validation_0-rmse:0.11583
# [46]	validation_0-rmse:0.11567
# [47]	validation_0-rmse:0.11553
# [48]	validation_0-rmse:0.11534
# [49]	validation_0-rmse:0.11518
# [50]	validation_0-rmse:0.11506
# [51]	validation_0-rmse:0.11489
# [52]	validation_0-rmse:0.11475
# [53]	validation_0-rmse:0.11466
# [54]	validation_0-rmse:0.11451
# [55]	validation_0-rmse:0.11434
# [56]	validation_0-rmse:0.11422
# [57]	validation_0-rmse:0.11411
# [58]	validation_0-rmse:0.11396
# [59]	validation_0-rmse:0.11385
# [60]	validation_0-rmse:0.11374
# [61]	validation_0-rmse:0.11367
# [62]	validation_0-rmse:0.11361
# [63]	validation_0-rmse:0.11354
# [64]	validation_0-rmse:0.11348
# [65]	validation_0-rmse:0.11339
# [66]	validation_0-rmse:0.11335
# [67]	validation_0-rmse:0.11329
# [68]	validation_0-rmse:0.11321
# [69]	validation_0-rmse:0.11315
# [70]	validation_0-rmse:0.11310
# [71]	validation_0-rmse:0.11304
# [72]	validation_0-rmse:0.11296
# [73]	validation_0-rmse:0.11293
# [74]	validation_0-rmse:0.11289
# [75]	validation_0-rmse:0.11285
# [76]	validation_0-rmse:0.11280
# [77]	validation_0-rmse:0.11274
# [78]	validation_0-rmse:0.11273
# [79]	validation_0-rmse:0.11269
# [80]	validation_0-rmse:0.11264
# [81]	validation_0-rmse:0.11259
# [82]	validation_0-rmse:0.11256
# [83]	validation_0-rmse:0.11250
# [84]	validation_0-rmse:0.11246
# [85]	validation_0-rmse:0.11246
# [86]	validation_0-rmse:0.11241
# [87]	validation_0-rmse:0.11240
# [88]	validation_0-rmse:0.11236
# [89]	validation_0-rmse:0.11236
# [90]	validation_0-rmse:0.11234
# [91]	validation_0-rmse:0.11233
# [92]	validation_0-rmse:0.11233
# [93]	validation_0-rmse:0.11228
# [94]	validation_0-rmse:0.11224
# [95]	validation_0-rmse:0.11221
# [96]	validation_0-rmse:0.11217
# [97]	validation_0-rmse:0.11214
# [98]	validation_0-rmse:0.11212
# [99]	validation_0-rmse:0.11211
# [100]	validation_0-rmse:0.11209
# [101]	validation_0-rmse:0.11208
# [102]	validation_0-rmse:0.11206
# [103]	validation_0-rmse:0.11204
# [104]	validation_0-rmse:0.11203
# [105]	validation_0-rmse:0.11201
# [106]	validation_0-rmse:0.11200
# [107]	validation_0-rmse:0.11199
# [108]	validation_0-rmse:0.11197
# [109]	validation_0-rmse:0.11194
# [110]	validation_0-rmse:0.11192
# [111]	validation_0-rmse:0.11190
# [112]	validation_0-rmse:0.11189
# [113]	validation_0-rmse:0.11189
# [114]	validation_0-rmse:0.11187
# [115]	validation_0-rmse:0.11185
# [116]	validation_0-rmse:0.11183
# [117]	validation_0-rmse:0.11183
# [118]	validation_0-rmse:0.11183
# [119]	validation_0-rmse:0.11180
# [120]	validation_0-rmse:0.11179
# [121]	validation_0-rmse:0.11177
# [607]	validation_0-rmse:0.11213
# [608]	validation_0-rmse:0.11215
# [609]	validation_0-rmse:0.11215
# [610]	validation_0-rmse:0.11216
# [611]	validation_0-rmse:0.11217
# [612]	validation_0-rmse:0.11218
# [613]	validation_0-rmse:0.11219
# [614]	validation_0-rmse:0.11219
# [615]	validation_0-rmse:0.11220
# [616]	validation_0-rmse:0.11220
# [617]	validation_0-rmse:0.11219
# [618]	validation_0-rmse:0.11220
# [619]	validation_0-rmse:0.11219
# [620]	validation_0-rmse:0.11220
# [621]	validation_0-rmse:0.11219
# [622]	validation_0-rmse:0.11218
# [623]	validation_0-rmse:0.11218
# [624]	validation_0-rmse:0.11216
# [625]	validation_0-rmse:0.11216
# [626]	validation_0-rmse:0.11217
# [627]	validation_0-rmse:0.11216
# [628]	validation_0-rmse:0.11216
# [629]	validation_0-rmse:0.11216
# [630]	validation_0-rmse:0.11215
# [631]	validation_0-rmse:0.11215
# [632]	validation_0-rmse:0.11215
# [633]	validation_0-rmse:0.11215
# [634]	validation_0-rmse:0.11215
# [635]	validation_0-rmse:0.11213
# [636]	validation_0-rmse:0.11213
# [637]	validation_0-rmse:0.11213
# [638]	validation_0-rmse:0.11212
# [639]	validation_0-rmse:0.11213
# [640]	validation_0-rmse:0.11213
# [641]	validation_0-rmse:0.11214
# [642]	validation_0-rmse:0.11213
# [643]	validation_0-rmse:0.11212
# [644]	validation_0-rmse:0.11213
# [645]	validation_0-rmse:0.11212
# [646]	validation_0-rmse:0.11212
# [647]	validation_0-rmse:0.11212
# [648]	validation_0-rmse:0.11214
# [649]	validation_0-rmse:0.11215
# [650]	validation_0-rmse:0.11214
# [651]	validation_0-rmse:0.11214
# [652]	validation_0-rmse:0.11214
# [653]	validation_0-rmse:0.11214
# [654]	validation_0-rmse:0.11215
# [655]	validation_0-rmse:0.11215
# [656]	validation_0-rmse:0.11215
# [657]	validation_0-rmse:0.11215
# [658]	validation_0-rmse:0.11216
# [659]	validation_0-rmse:0.11216
# [660]	validation_0-rmse:0.11216
# [661]	validation_0-rmse:0.11217
# [662]	validation_0-rmse:0.11219
# [663]	validation_0-rmse:0.11219
# [664]	validation_0-rmse:0.11218
# [665]	validation_0-rmse:0.11220
# [666]	validation_0-rmse:0.11221
# [667]	validation_0-rmse:0.11221
# [668]	validation_0-rmse:0.11221
# [669]	validation_0-rmse:0.11220
# [670]	validation_0-rmse:0.11220
# [671]	validation_0-rmse:0.11220
# [672]	validation_0-rmse:0.11221
# [673]	validation_0-rmse:0.11222
# [674]	validation_0-rmse:0.11220
# [675]	validation_0-rmse:0.11219
# [676]	validation_0-rmse:0.11221
# [677]	validation_0-rmse:0.11221
# [678]	validation_0-rmse:0.11222
# [679]	validation_0-rmse:0.11222
# [680]	validation_0-rmse:0.11222
# [681]	validation_0-rmse:0.11222
# [682]	validation_0-rmse:0.11221
# [683]	validation_0-rmse:0.11222
# [684]	validation_0-rmse:0.11223
# [685]	validation_0-rmse:0.11223
# [686]	validation_0-rmse:0.11223
# [687]	validation_0-rmse:0.11223
# [688]	validation_0-rmse:0.11223
# [689]	validation_0-rmse:0.11223
# [690]	validation_0-rmse:0.11223
# [691]	validation_0-rmse:0.11223
# [692]	validation_0-rmse:0.11223
# [693]	validation_0-rmse:0.11224
# [694]	validation_0-rmse:0.11224
# [695]	validation_0-rmse:0.11224
# [696]	validation_0-rmse:0.11224
# [697]	validation_0-rmse:0.11225
# [698]	validation_0-rmse:0.11225
# [699]	validation_0-rmse:0.11223
# [700]	validation_0-rmse:0.11224
# [701]	validation_0-rmse:0.11223
# [702]	validation_0-rmse:0.11224
# [703]	validation_0-rmse:0.11223
# [704]	validation_0-rmse:0.11223
# [705]	validation_0-rmse:0.11222
# [706]	validation_0-rmse:0.11221
# [707]	validation_0-rmse:0.11221
# [708]	validation_0-rmse:0.11221
# [709]	validation_0-rmse:0.11221
# [710]	validation_0-rmse:0.11221
# [711]	validation_0-rmse:0.11221
# [712]	validation_0-rmse:0.11221
# [713]	validation_0-rmse:0.11219
# [714]	validation_0-rmse:0.11219
# [715]	validation_0-rmse:0.11219
# [716]	validation_0-rmse:0.11219
# [717]	validation_0-rmse:0.11220
# [718]	validation_0-rmse:0.11220
# [719]	validation_0-rmse:0.11218
# [720]	validation_0-rmse:0.11218
# [721]	validation_0-rmse:0.11218
# [722]	validation_0-rmse:0.11218
# [723]	validation_0-rmse:0.11218
# [724]	validation_0-rmse:0.11218
# [725]	validation_0-rmse:0.11218
# [726]	validation_0-rmse:0.11219
# [727]	validation_0-rmse:0.11220
# [728]	validation_0-rmse:0.11219
# [729]	validation_0-rmse:0.11219
# [730]	validation_0-rmse:0.11220
# [731]	validation_0-rmse:0.11220
# [732]	validation_0-rmse:0.11221
# [733]	validation_0-rmse:0.11220
# [734]	validation_0-rmse:0.11219
# [735]	validation_0-rmse:0.11217
# [736]	validation_0-rmse:0.11218
# [737]	validation_0-rmse:0.11220
# [738]	validation_0-rmse:0.11221
# [739]	validation_0-rmse:0.11222
# [740]	validation_0-rmse:0.11222
# [741]	validation_0-rmse:0.11221
# [742]	validation_0-rmse:0.11221
# [743]	validation_0-rmse:0.11221
# [744]	validation_0-rmse:0.11221
# [745]	validation_0-rmse:0.11221
# [746]	validation_0-rmse:0.11221
# [747]	validation_0-rmse:0.11221
# [748]	validation_0-rmse:0.11221
# [749]	validation_0-rmse:0.11221
# [750]	validation_0-rmse:0.11221
# [751]	validation_0-rmse:0.11220
# [752]	validation_0-rmse:0.11220
# [753]	validation_0-rmse:0.11221
# [754]	validation_0-rmse:0.11220
# [755]	validation_0-rmse:0.11221
# [756]	validation_0-rmse:0.11221
# [757]	validation_0-rmse:0.11220
# [758]	validation_0-rmse:0.11222
# [759]	validation_0-rmse:0.11222
# [760]	validation_0-rmse:0.11224
# [761]	validation_0-rmse:0.11224
# [762]	validation_0-rmse:0.11225
# [763]	validation_0-rmse:0.11226
# [764]	validation_0-rmse:0.11226
# [765]	validation_0-rmse:0.11225
# [766]	validation_0-rmse:0.11225
# [767]	validation_0-rmse:0.11225
# [768]	validation_0-rmse:0.11226
# [769]	validation_0-rmse:0.11225
# [770]	validation_0-rmse:0.11226
# [771]	validation_0-rmse:0.11226
# [772]	validation_0-rmse:0.11227
# [773]	validation_0-rmse:0.11227
# [774]	validation_0-rmse:0.11227
# [775]	validation_0-rmse:0.11227
# [776]	validation_0-rmse:0.11226
# [777]	validation_0-rmse:0.11226
# [778]	validation_0-rmse:0.11226
# [779]	validation_0-rmse:0.11227
# [780]	validation_0-rmse:0.11228
# [781]	validation_0-rmse:0.11228
# [782]	validation_0-rmse:0.11228
# [783]	validation_0-rmse:0.11229
# [784]	validation_0-rmse:0.11228
# [785]	validation_0-rmse:0.11227
# [786]	validation_0-rmse:0.11228
# [787]	validation_0-rmse:0.11227
# [788]	validation_0-rmse:0.11227
# [789]	validation_0-rmse:0.11226
# [790]	validation_0-rmse:0.11226
# [791]	validation_0-rmse:0.11227
# [792]	validation_0-rmse:0.11227
# [793]	validation_0-rmse:0.11227
# [794]	validation_0-rmse:0.11228
# [795]	validation_0-rmse:0.11228
# [796]	validation_0-rmse:0.11228
# [797]	validation_0-rmse:0.11229
# [798]	validation_0-rmse:0.11229
# [799]	validation_0-rmse:0.11230
# [800]	validation_0-rmse:0.11230
# [801]	validation_0-rmse:0.11231
# [802]	validation_0-rmse:0.11231
# [803]	validation_0-rmse:0.11231
# [804]	validation_0-rmse:0.11231
# [805]	validation_0-rmse:0.11231
# [806]	validation_0-rmse:0.11231
# [807]	validation_0-rmse:0.11230
# [808]	validation_0-rmse:0.11230
# [809]	validation_0-rmse:0.11231
# [810]	validation_0-rmse:0.11231
# [811]	validation_0-rmse:0.11231
# [812]	validation_0-rmse:0.11230
# [813]	validation_0-rmse:0.11231
# [814]	validation_0-rmse:0.11231
# [815]	validation_0-rmse:0.11231
# [816]	validation_0-rmse:0.11231
# [817]	validation_0-rmse:0.11231
# [818]	validation_0-rmse:0.11232
# [819]	validation_0-rmse:0.11232
# [820]	validation_0-rmse:0.11231
# [821]	validation_0-rmse:0.11232
# [822]	validation_0-rmse:0.11231
# [823]	validation_0-rmse:0.11232
# [824]	validation_0-rmse:0.11232
# [825]	validation_0-rmse:0.11233
# [826]	validation_0-rmse:0.11233
# [827]	validation_0-rmse:0.11233
# [828]	validation_0-rmse:0.11232
# [829]	validation_0-rmse:0.11233
# [830]	validation_0-rmse:0.11233
# [831]	validation_0-rmse:0.11233
# [832]	validation_0-rmse:0.11233
# [833]	validation_0-rmse:0.11234
# [834]	validation_0-rmse:0.11234
# [835]	validation_0-rmse:0.11234
# [836]	validation_0-rmse:0.11235
# [837]	validation_0-rmse:0.11235
# [838]	validation_0-rmse:0.11235
# [839]	validation_0-rmse:0.11235
# [840]	validation_0-rmse:0.11235
# [841]	validation_0-rmse:0.11236
# [842]	validation_0-rmse:0.11237
# [843]	validation_0-rmse:0.11237
# [844]	validation_0-rmse:0.11238
# [845]	validation_0-rmse:0.11238
# [846]	validation_0-rmse:0.11238
# [847]	validation_0-rmse:0.11239
# [848]	validation_0-rmse:0.11239
# [849]	validation_0-rmse:0.11239
# [850]	validation_0-rmse:0.11240
# [851]	validation_0-rmse:0.11240
# [852]	validation_0-rmse:0.11240
# [853]	validation_0-rmse:0.11241
# [854]	validation_0-rmse:0.11241
# [855]	validation_0-rmse:0.11241
# [856]	validation_0-rmse:0.11242
# [857]	validation_0-rmse:0.11243
# [858]	validation_0-rmse:0.11242
# [859]	validation_0-rmse:0.11242
# [860]	validation_0-rmse:0.11242
# [861]	validation_0-rmse:0.11242
# [862]	validation_0-rmse:0.11241
# [863]	validation_0-rmse:0.11241
# [864]	validation_0-rmse:0.11241
# [865]	validation_0-rmse:0.11240
# [866]	validation_0-rmse:0.11240
# [867]	validation_0-rmse:0.11241
# [868]	validation_0-rmse:0.11241
# [869]	validation_0-rmse:0.11241
# [870]	validation_0-rmse:0.11242
# [871]	validation_0-rmse:0.11242
# [872]	validation_0-rmse:0.11241
# [873]	validation_0-rmse:0.11241
# [874]	validation_0-rmse:0.11242
# [875]	validation_0-rmse:0.11241
# [876]	validation_0-rmse:0.11242
# [877]	validation_0-rmse:0.11242
# [878]	validation_0-rmse:0.11243
# [879]	validation_0-rmse:0.11244
# [880]	validation_0-rmse:0.11245
# [881]	validation_0-rmse:0.11244
# [882]	validation_0-rmse:0.11245
# [883]	validation_0-rmse:0.11245
# [884]	validation_0-rmse:0.11246
# [885]	validation_0-rmse:0.11246
# [886]	validation_0-rmse:0.11246
# [887]	validation_0-rmse:0.11246
# [888]	validation_0-rmse:0.11246
# [889]	validation_0-rmse:0.11246
# [890]	validation_0-rmse:0.11246
# [891]	validation_0-rmse:0.11246
# [892]	validation_0-rmse:0.11247
# [893]	validation_0-rmse:0.11248
# [894]	validation_0-rmse:0.11249
# [895]	validation_0-rmse:0.11250
# [896]	validation_0-rmse:0.11249
# [897]	validation_0-rmse:0.11249
# [898]	validation_0-rmse:0.11250
# [899]	validation_0-rmse:0.11250
# [900]	validation_0-rmse:0.11250
# [901]	validation_0-rmse:0.11251
# [902]	validation_0-rmse:0.11251
# [903]	validation_0-rmse:0.11252
# [904]	validation_0-rmse:0.11252
# [905]	validation_0-rmse:0.11252
# [906]	validation_0-rmse:0.11252
# [907]	validation_0-rmse:0.11253
# [908]	validation_0-rmse:0.11253
# [909]	validation_0-rmse:0.11254
# [910]	validation_0-rmse:0.11253
# [911]	validation_0-rmse:0.11253
# [912]	validation_0-rmse:0.11252
# [913]	validation_0-rmse:0.11252
# [914]	validation_0-rmse:0.11253
# [915]	validation_0-rmse:0.11252
# [916]	validation_0-rmse:0.11252
# [917]	validation_0-rmse:0.11252
# [918]	validation_0-rmse:0.11253
# [919]	validation_0-rmse:0.11253
# [920]	validation_0-rmse:0.11253
# [921]	validation_0-rmse:0.11253
# [922]	validation_0-rmse:0.11252
# [923]	validation_0-rmse:0.11252
# [924]	validation_0-rmse:0.11251
# [925]	validation_0-rmse:0.11252
# [926]	validation_0-rmse:0.11251
# [927]	validation_0-rmse:0.11253
# [928]	validation_0-rmse:0.11252
# [929]	validation_0-rmse:0.11252
# [930]	validation_0-rmse:0.11252
# [931]	validation_0-rmse:0.11253
# [932]	validation_0-rmse:0.11253
# [933]	validation_0-rmse:0.11254
# [934]	validation_0-rmse:0.11254
# [935]	validation_0-rmse:0.11255
# [936]	validation_0-rmse:0.11255
# [937]	validation_0-rmse:0.11256
# [938]	validation_0-rmse:0.11256
# [939]	validation_0-rmse:0.11255
# [940]	validation_0-rmse:0.11253
# [941]	validation_0-rmse:0.11253
# [942]	validation_0-rmse:0.11254
# [943]	validation_0-rmse:0.11255
# [944]	validation_0-rmse:0.11255
# [945]	validation_0-rmse:0.11255
# [946]	validation_0-rmse:0.11255
# [947]	validation_0-rmse:0.11255
# [948]	validation_0-rmse:0.11256
# [949]	validation_0-rmse:0.11256
# [950]	validation_0-rmse:0.11256
# [951]	validation_0-rmse:0.11257
# [952]	validation_0-rmse:0.11258
# [953]	validation_0-rmse:0.11258
# [954]	validation_0-rmse:0.11258
# [955]	validation_0-rmse:0.11258
# [956]	validation_0-rmse:0.11258
# [957]	validation_0-rmse:0.11259
# [958]	validation_0-rmse:0.11259
# [959]	validation_0-rmse:0.11259
# [960]	validation_0-rmse:0.11259
# [961]	validation_0-rmse:0.11259
# [962]	validation_0-rmse:0.11259
# [963]	validation_0-rmse:0.11259
# [964]	validation_0-rmse:0.11259
# [965]	validation_0-rmse:0.11260
# [966]	validation_0-rmse:0.11260
# [967]	validation_0-rmse:0.11261
# [968]	validation_0-rmse:0.11261
# [969]	validation_0-rmse:0.11261
# [970]	validation_0-rmse:0.11261
# [971]	validation_0-rmse:0.11261
# [972]	validation_0-rmse:0.11262
# [973]	validation_0-rmse:0.11263
# [974]	validation_0-rmse:0.11263
# [975]	validation_0-rmse:0.11262
# [976]	validation_0-rmse:0.11262
# [977]	validation_0-rmse:0.11262
# [978]	validation_0-rmse:0.11262
# [979]	validation_0-rmse:0.11262
# [980]	validation_0-rmse:0.11263
# [981]	validation_0-rmse:0.11263
# [982]	validation_0-rmse:0.11264
# [983]	validation_0-rmse:0.11265
# [984]	validation_0-rmse:0.11264
# [985]	validation_0-rmse:0.11265
# [986]	validation_0-rmse:0.11265
# [987]	validation_0-rmse:0.11265
# [988]	validation_0-rmse:0.11266
# [989]	validation_0-rmse:0.11266
# [990]	validation_0-rmse:0.11267
# [991]	validation_0-rmse:0.11268
# [992]	validation_0-rmse:0.11267
# [993]	validation_0-rmse:0.11267
# [994]	validation_0-rmse:0.11266
# [995]	validation_0-rmse:0.11266
# [996]	validation_0-rmse:0.11266
# [997]	validation_0-rmse:0.11266
# [998]	validation_0-rmse:0.11267
# [999]	validation_0-rmse:0.11268
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005019 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2844
# [LightGBM] [Info] Number of data points in the train set: 18000, number of used features: 20
# [LightGBM] [Info] Start training from score 0.510943
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [222]	valid_0's rmse: 0.110711
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Best Ridge alpha: 0.1
# ✅ Validation RMSE: 0.1102
# ✅ Custom Score: 88.98/100
# ✅ 'submission.csv' created successfully.
